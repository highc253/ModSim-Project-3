# %%
# %matplotlib inline

from modsim import *
import math

# %% [markdown]
# Time to set the intial conditions; this sets up all the parameters for the rocket, its engine, and the environment it's in.

# %%
# Set initial conditions.  These conditions will be used in make_system to generate a system.

condition = Condition(# Set cap for simulation time
                      duration=105, #*s,
                      
                      # -----------------------------------------
                      # Initial state and environmental properties
                      # -----------------------------------------
                      y=0, #*m, 
                      g=9.8, #*m/s**2,
                      velocity=0, #*m/s,
                      rho_air=1.2, #*kg/m**3,
                      
                      # -----------------------------------------
                      # Properties of the rocket body
                      # -----------------------------------------
                      m_rocket=50, #*gm,
                      diameter=4, #*cm, 
                      C_d=0.75, 
                      thetaCone=75,
                      
                      # -----------------------------------------
                      # Properties of the engine and exhaust
                      # -----------------------------------------
                      m_engine=52.0159, #*gm,
                      v_exhaust=5000, # * m/s,
                      rho_fuel=1.6426, #*gm/cm**3,
                      engineSA=4.5234, #*cm**2,
                      burnRate=0.1, #*cm/s,   THIS USED TO READ 1 (mm) which I think was wrong
                      
                      )

# Set initial conditions.  These conditions will be used in make_system to generate a system.

condition2 = Condition(# Set cap for simulation time
                      duration=105, #*s,
                      
                      # -----------------------------------------
                      # Initial state and environmental properties
                      # -----------------------------------------
                      y=0, #*m, 
                      g=9.8, #*m/s**2,
                      velocity=0, #*m/s,
                      rho_air=1.2, #*kg/m**3,
                      
                      # -----------------------------------------
                      # Properties of the rocket body
                      # -----------------------------------------
                      m_rocket=50, #*gm,
                      diameter=4, #*cm, 
                      C_d=0.75, 
                      thetaCone=75,
                      
                      # -----------------------------------------
                      # Properties of the engine and exhaust
                      # -----------------------------------------
                      m_engine=0, #*gm,
                      v_exhaust=5000, # * m/s,
                      rho_fuel=1.6426, #*gm/cm**3,
                      engineSA=4.5234, #*cm**2,
                      burnRate=0.1, #*cm/s,   THIS USED TO READ 1 (mm) which I think was wrong
                      
                      )

# %% [markdown]
# Let's define a function to make systems for us.  This needs to copy certain parameters from the initial Condition object to the system and calculate the surface area of the rocket that will need to be accounted for in the drag calculation.

# %%
# Takes in an initial condition and generates a full system

def make_system(condition):
    
    unpack(condition)
    
    vy = velocity
    init = State(m_engine=m_engine,y=y,vy=vy)
    
    r = diameter/2
    h = r*math.tan(thetaCone)
    coneSA = 3.14159 * r * (r + sqrt(r*r + h*h))
    
    ts = linspace(0,duration,101)
    
    return System(init=init,
                  g=g,
                  rho_air=rho_air,
                  C_d=C_d,
                  engineSA=engineSA,
                  m_engine=m_engine,
                  m_rocket=m_rocket,
                  rho_fuel=rho_fuel,
                  burnRate=burnRate,
                  ts=ts,
                  coneSA=coneSA,
                  v_exhaust=v_exhaust)

# %%
# Takes in an initial condition and generates a full system

def make_system2(condition2, t0):
    
    unpack(condition2)
    vy = velocity
    #init = State(m_engine=m_engine,y=y,vy=vy)
    
    r = diameter/2
    h = r*math.tan(thetaCone)
    coneSA = 3.14159 * r * (r + sqrt(r*r + h*h))
    
    ts = linspace(t0,duration,101)
    
    return System(init=condition2.init,
                  g=g,
                  rho_air=rho_air,
                  C_d=C_d,
                  engineSA=engineSA,
                  m_engine=0,
                  m_rocket=m_rocket,
                  ts=ts,
                  coneSA=coneSA)

# %%
# Run this function UNTIL THE ENGINE RUNS OUT OF FUEL

def slope_func1(state,t,system):
    
    unpack(system)
        
    # Grab the initial state of everything
    m_engine, y, vy = state
    
    # Calculate m_dot
    m_dot = -1 * rho_fuel * engineSA * burnRate
    
    m = m_rocket + m_engine
    
    # Calculate the acceleration due to drag
    f_drag = rho_air * C_d * vy*vy * coneSA / 2
    a_drag = f_drag / m
    
    ay = (v_exhaust * -1 * m_dot) / m - g - a_drag
    
    if m_engine < 0:
        print("Engine mass " + str(m_engine) + " at time " + str(t))
            
    return m_dot, vy, ay

# %%
# Run this function AFTER THE ENGINE RUNS OUT OF FUEL

def slope_func2(state,t,system):
    
    unpack(system)
    
    # Grab the initial state of everything
    m_engine, y, vy = state
    
    m = m_rocket
    
    # Calculate the acceleration due to drag
    f_drag = rho_air * C_d * vy*vy * coneSA / 2
    a_drag = f_drag / m
    print(a_drag)
    # Calculate the net acceleration on the rocket
    ay = -1 * g - a_drag
    #print(t, vy)
    #if vy < 0:
    #    print("Velocity is " + str(vy) + "at time " + str(t))
       
    return 0, vy, ay

# %%
system = make_system(condition)
slope_func1(system.init, 0, system)
# Out:
# (-0.74301368400000001, 0.0, 26.616562712283088)

# %%
system = make_system(condition2)
slope_func2(system.init, 0, system)
# Out:
# 0 0.0
# (0, 0.0, -9.8000000000000007)

# %%
testCondition1 = condition
testCondition1.duration = 80

system = make_system(testCondition1)
run_odeint(system,slope_func1)

plot(system.results.y)
# Out:
# Engine mass -1.90072738871 at time 72.56478386568584
# Engine mass -1.90072738871 at time 72.56478386568584
# Engine mass -6.80651819208 at time 79.16734167721725
# Engine mass -12.8642626626 at time 87.32027963911446
# Engine mass -12.8642626626 at time 87.32027963911446
# Engine mass -12.8642626626 at time 87.32027963911446
# Engine mass -12.8642626626 at time 87.32027963911446
# Engine mass -12.8642624709 at time 87.32027963911446
# Engine mass -12.8642626626 at time 87.32027963911446
# Engine mass -12.8642626626 at time 87.32027963911446
# Engine mass -12.8642626626 at time 87.32027963911446

# %%
testCondition1 = condition
testCondition1.duration = 70

system = make_system(testCondition1)
run_odeint(system,slope_func1)

#plot(system.results.y)
system.results.tail()
# Out:
# Engine mass -1.90072754962 at time 72.56478408225217
# Engine mass -1.90072754962 at time 72.56478408225217
#       m_engine            y         vy
# 67.2  2.085380  1058.224096  16.484284
# 67.9  1.565271  1069.767692  16.497419
# 68.6  1.045161  1081.320480  16.510544
# 69.3  0.525052  1092.882451  16.523658
# 70.0  0.004942  1104.453598  16.536762

# %%
testCondition2 = condition
testCondition2.duration = 80
testCondition2.init = system.results.iloc[-1]

system2 = make_system2(testCondition2, 70.0)
print(system2.init)
run_odeint(system2,slope_func2)

plot(system2.results.y)
# Out:
# m_engine       0.004942
# 8.40080460295e+19
# 8.40080527101e+19
# 9.34587402583e+19
# 9.34587948123e+19
# 1.04598819076e+20
# 1.04598878876e+20
# 1.17856192617e+20
# 1.17856301552e+20
# 1.15176763222e+20
# 1.15176814886e+20
# 1.27444401023e+20
# 1.27444411158e+20
# 1.41781576117e+20
# 1.41781658878e+20
# 1.58681631997e+20
# 1.58681722716e+20
# 1.78793729705e+20
# 1.78793894965e+20
# 1.74728901508e+20
# 1.74728979885e+20
# 1.93339520674e+20
# 1.93339536049e+20
# 2.15089731262e+20
# 2.15089856815e+20
# 2.40727959989e+20
# 2.40728097613e+20
# 2.71239016571e+20
# 2.71239267279e+20
# 2.65072469206e+20
# 2.65072588107e+20
# 2.93305707857e+20
# 2.93305731181e+20
# 3.26301863481e+20
# 3.26302053951e+20
# 3.65196336782e+20
# 3.65196545565e+20
# 4.11483133279e+20
# 4.11483513615e+20
# 4.02128172981e+20
# 4.0212835336e+20
# 4.44959405928e+20
# 4.44959441313e+20
# 4.95016221774e+20
# 4.95016510726e+20
# 5.54021080085e+20
# 5.54021396819e+20
# 6.24240461845e+20
# 6.24241038833e+20
# 6.10048519903e+20
# 6.10048793547e+20
# 6.75025639191e+20
# 6.75025692871e+20
# 7.50964328568e+20
# 7.50964766922e+20
# 8.40477645212e+20
# 8.40478125713e+20
# 9.47003953957e+20
# 9.47004829277e+20
# 9.25474069313e+20
# 9.25474484444e+20
# 1.0240476041e+21
# 1.02404768554e+21
# 1.13925038811e+21
# 1.13925105312e+21
# 1.27504655957e+21
# 1.27504728852e+21
# 1.43665228965e+21
# 1.43665361755e+21
# 1.40399037949e+21
# 1.40399100927e+21
# 1.55353135433e+21
# 1.55353147787e+21
# 1.72829973068e+21
# 1.72830073952e+21
# 1.93430930418e+21
# 1.93431041003e+21
# 2.17947326698e+21
# 2.17947528148e+21
# 2.12992351819e+21
# 2.12992447359e+21
# 2.3567846448e+21
# 2.35678483222e+21
# 2.6219169993e+21
# 2.62191852977e+21
# 2.93444381001e+21
# 2.93444548763e+21
# 3.30636978457e+21
# 3.30637284067e+21
# 3.23120034127e+21
# 3.23120179066e+21
# 3.57535999936e+21
# 3.57536028369e+21
# 3.97757902136e+21
# 3.97758134316e+21
# 4.45169780023e+21
# 4.45170034527e+21
# 5.01592807695e+21
# 5.0159327132e+21
# 4.90189227759e+21
# 4.90189447639e+21
# 5.42399966558e+21
# 5.42400009691e+21
# 6.03418600798e+21
# 6.03418953026e+21
# 6.75344787208e+21
# 6.75345173303e+21
# 7.60941337843e+21
# 7.60942041184e+21
# 7.43641537605e+21
# 7.43641871173e+21
# 8.2284783566e+21
# 8.22847901096e+21
# 9.15416150948e+21
# 9.15416685297e+21
# 1.02453176758e+22
# 1.0245323533e+22
# 1.15438600941e+22
# 1.15438707641e+22
# 1.12814134854e+22
# 1.12814185458e+22
# 1.2483012581e+22
# 1.24830135736e+22
# 1.38873201507e+22
# 1.3887328257e+22
# 1.55426585452e+22
# 2.5430922469e+24
# 2.81395928922e+24
# 2.81395951299e+24
# 3.13052264321e+24
# 3.13052447057e+24
# 3.50367414183e+24
# 3.50367614488e+24
# 3.94774719421e+24
# 3.94775084313e+24
# 3.85799620494e+24
# 3.85799793549e+24
# 4.26891676522e+24
# 4.2689171047e+24
# 4.74915918173e+24
# 4.74916195392e+24
# 5.31524863952e+24
# 5.31525167825e+24
# 5.98892963603e+24
# 5.98893517162e+24
# 5.85277290341e+24
# 5.85277552874e+24
# 6.47615991393e+24
# 6.47616042894e+24
# 7.20471164217e+24
# 7.20471584772e+24
# 8.06349761906e+24
# 8.06350222897e+24
# 9.08550533311e+24
# 9.08551373088e+24
# 8.87894877025e+24
# 8.878952753e+24
# 9.82465799588e+24
# 9.82465877717e+24
# 1.092990735e+25
# 1.092991373e+25
# 1.2232728563e+25
# 1.22327355564e+25
# 1.37831653021e+25
# 1.3783178042e+25
# 1.34698086814e+25
# 1.34698147234e+25
# 1.49044968036e+25
# 1.49044979888e+25
# 1.65812152679e+25
# 1.65812249467e+25
# 1.85576601084e+25
# 1.85576707178e+25
# 2.09097500676e+25
# 2.09097693946e+25
# 2.04343724254e+25
# 2.04343815915e+25
# 2.26108659524e+25
# 2.26108677505e+25
# 2.51545315948e+25
# 2.51545462781e+25
# 2.81528971178e+25
# 2.81529132128e+25
# 3.1721135045e+25
# 3.1721164365e+25
# 3.09999634221e+25
# 3.09999773275e+25
# 3.43018127923e+25
# 3.43018155201e+25
# 3.81606805976e+25
# 3.81607028728e+25
# 4.27093508284e+25
# 4.27093752453e+25
# 4.81225459546e+25
# 4.81225904345e+25
# 4.70284925889e+25
# 4.7028513684e+25
# 5.20375629713e+25
# 5.20375671095e+25
# 5.7891658136e+25
# 5.78916919287e+25
# 6.47922180277e+25
# 6.47922550694e+25
# 7.30043053584e+25
# 7.30043728366e+25
# 7.13445717676e+25
# 7.134460377e+25
# 7.89435816807e+25
# 7.89435879585e+25
# 8.78245363873e+25
# 8.78245876524e+25
# 9.82930303429e+25
# 9.82930865371e+25
# 1.10751176919e+26
# 1.10751279286e+26
# 1.08233278178e+26
# 1.08233326727e+26
# 1.19761355696e+26
# 1.1976136522e+26
# 1.33234207484e+26
# 1.33234285255e+26
# 1.49115435591e+26
# 1.4911552084e+26
# 1.68015066082e+26
# 1.68015221379e+26
# 1.64195287953e+26
# 1.64195361604e+26
# 1.81683957236e+26
# 1.81683971685e+26
# 2.02122946205e+26
# 2.02123064189e+26
# 2.2621556232e+26
# 2.26215691647e+26
# 2.54887245584e+26
# 2.54887481177e+26
# 2.49092451412e+26
# 2.49092563145e+26
# 2.75623636066e+26
# 2.75623657984e+26
# 3.06630603015e+26
# 3.06630782002e+26
# 3.43180304801e+26
# 3.43180500997e+26
# 3.86676680122e+26
# 3.86677037529e+26
# 3.7788568798e+26
# 3.77885857485e+26
# C:\ProgramData\Miniconda3\lib\site-packages\scipy\integrate\odepack.py:218: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
